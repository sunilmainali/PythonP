# %%
import pandas as pd
import numpy as np

# %%
titanic = pd.read_csv('Titanic_data.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### DataFrame Manipulation

# %% [markdown]
# ##### Inserting and Deleting COlumn / Rows

# %%
# Dropping a column
titanic.drop('PassengerId', axis = 1,inplace=True)

# %%
titanic.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
# Insering a column
titanic['Random']=np.arange(1,892)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Random
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       2
# 2      0  STON/O2. 3101282   7.9250   NaN        S       3
# 3      0            113803  53.1000  C123        S       4
# ...

# %%
titanic.drop('Random',axis=1,inplace=True)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Using loc
titanic.loc[3,'Cabin']
# Out:
# 'C123'

# %%
titanic.loc[900]=[0,3,'Ram','male',24,1,0,12324,33,'NaN','S','mr']

# %%
titanic.tail()
# Out:
#      PassengerId  Survived Pclass                                      Name  \
# 887          888         1      1              Graham, Miss. Margaret Edith
# 888          889         0      3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1      1                     Behr, Mr. Karl Howell
# 890          891         0      3                       Dooley, Mr. Patrick
# 900            0         3    Ram                                      male
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 887  female  19.0      0      0      112053   30.0   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369   30.0  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q
# 900      24   1.0      0  12324          33    NaN     S       mr

# %%
# Dropping a row
titanic.drop(index=900,axis=0,inplace=True)

# %%
titanic.tail()
# Out:
#      PassengerId  Survived Pclass                                      Name  \
# 886          887         0      2                     Montvila, Rev. Juozas
# 887          888         1      1              Graham, Miss. Margaret Edith
# 888          889         0      3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1      1                     Behr, Mr. Karl Howell
# 890          891         0      3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536   13.0   NaN        S
# 887  female  19.0      0      0      112053   30.0   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369   30.0  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# dropna method
titanic.dropna(subset='Embarked',axis=0)
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# ..           ...       ...    ...
# 886          887         0      2
# 887          888         1      1
# 888          889         0      3
# 889          890         1      1
# 890          891         0      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Imputation

# Method fillna()
# 1. Expert Advice
# 2. Mean Imputation <- Continuous Value
# 3. Mode Imputation <- Categorical Value
# 4. Median Imputation
# 5. Interpolation < -Continuous Values

# %%
titanic['Embarked'].fillna(titanic['Embarked'].mode()[0], inplace=True)

# %%
titanic.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# initials       0
# dtype: int64

# %%
titanic['Cabin'].fillna("Not in cabin,somwhere else!",inplace=True)
# Out:
# C:\Users\sunil\AppData\Local\Temp\ipykernel_11296\2152502037.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['Cabin'].fillna("Not in cabin,somwhere else!",inplace=True)

# %%
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         2
# dtype: int64

# %%
titanic['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
def get_initials(value):
    name=value.split(',')[1]
    initials=name.split('.')[0]
    return initials.strip()

# %%
titanic['initials']=titanic['Name'].apply(get_initials)

# %%
titanic.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0    male  22.0      1      0         A/5 21171   7.2500
# 1  female  38.0      1      0          PC 17599  71.2833
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3  female  35.0      1      0            113803  53.1000
# 4    male  35.0      0      0            373450   8.0500
#
#                          Cabin Embarked initials
# 0  Not in cabin,somwhere else!        S       Mr
# 1                          C85        C      Mrs
# ...

# %%
titanic['initials'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer'], dtype=object)

# %%
titanic['initials'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='initials'>

# %%
titanic[titanic['Age'].isna()].groupby('initials').size()
# Out:
# initials
# Dr          1
# Master      4
# Miss       36
# Mr        119
# Mrs        17
# dtype: int64

# %%
titanic.groupby('initials')['Age'].agg(NaN_Counts=lambda x: x.isna().sum(),NotNaN_counts=lambda x:x.notna().sum())
# Out:
#               NaN_Counts  NotNaN_counts
# initials
# Capt                   0              1
# Col                    0              2
# Don                    0              1
# Dr                     1              6
# Jonkheer               0              1
# Lady                   0              1
# Major                  0              2
# Master                 4             36
# Miss                  36            146
# Mlle                   0              2
# Mme                    0              1
# Mr                   119            398
# Mrs                   17            108
# Ms                     0              1
# Rev                    0              6
# Sir                    0              1
# the Countess           0              1

# %%
mean_age_by_initials=titanic.groupby('initials')['Age'].mean()
mean_age_by_initials
# Out:
# initials
# Capt            70.000000
# Col             58.000000
# Don             40.000000
# Dr              42.000000
# Jonkheer        38.000000
# Lady            48.000000
# Major           48.500000
# Master           4.574167
# Miss            21.773973
# Mlle            24.000000
# Mme             24.000000
# Mr              32.368090
# Mrs             35.898148
# Ms              28.000000
# Rev             43.166667
# Sir             49.000000
# the Countess    33.000000
# Name: Age, dtype: float64

# %%
titanic['Age'] = titanic['Age'].fillna(titanic['initials'].map(mean_age_by_initials))

# %%
titanic.sample(10)
# Out:
#      PassengerId  Survived Pclass                                     Name  \
# 732          733         0      2                     Knight, Mr. Robert J
# 356          357         1      1              Bowerman, Miss. Elsie Edith
# 716          717         1      1            Endres, Miss. Caroline Louise
# 373          374         0      1                      Ringhini, Mr. Sante
# 797          798         1      3                         Osman, Mrs. Mara
# 825          826         0      3                          Flynn, Mr. John
# 703          704         0      3                    Gallagher, Mr. Martin
# 605          606         0      3            Lindell, Mr. Edvard Bengtsson
# 472          473         1      2  West, Mrs. Edwy Arthur (Ada Mary Worth)
# 276          277         0      3        Lindblom, Miss. Augusta Charlotta
#
#         Sex       Age  SibSp  Parch      Ticket      Fare  \
# 732    male  32.36809      0      0      239855       0.0
# ...

# %%
titanic.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# initials       0
# dtype: int64
